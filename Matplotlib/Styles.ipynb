# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,11,10)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x,color='#650dbd',label='X VS X',lw=2,ls='--')
ax.plot(x,x**2,color='#34c0eb', label='X^2',lw=2,ls='-.')
ax.legend()
